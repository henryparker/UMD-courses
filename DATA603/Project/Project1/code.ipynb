# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report

from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

from sklearn.decomposition import PCA

# %%
train, test = pd.read_csv('TrainingData.csv'), pd.read_csv('TestingData.csv')
train_x, train_y = np.array(train.iloc[:, :-1]), np.array(train.iloc[:, -1])
test_x, test_y = np.array(test.iloc[:, :-1]), np.array(test.iloc[:, -1])

# %% [markdown]
# ## 1.1 Linear Discriminant Analysis
#
# - In the code, I firstyly calculate the vector w in function lda_projection_vector().
# - Then given the test data, their labels are predicted throught y = x.dot(w)
# - Then I equally split 100 different thresholds between min and max value of y
# - Finally, I calculate the accuracy of the prediction given different thresholds and plot the result

# %%
# Projection Vector w
def lda_projection_vector(X_train, y_train):
    # Split data into two classes
    class0 = X_train[y_train == 0]
    class1 = X_train[y_train == 1]
    
    # Calculate class means
    mean0 = np.mean(class0, axis=0)
    mean1 = np.mean(class1, axis=0)
    
    # Calculate within-class scatter matrices
    S_w = np.cov(class0, rowvar=False) * len(class0) + np.cov(class1, rowvar=False) * len(class1)
    
    # Compute w as the direction that maximizes the mean separation
    w = np.linalg.inv(S_w).dot(mean1 - mean0)
    return w

# Type1 and Type2 Error with threshold
def compute_error_rates(y_true, y_proj, threshold):
    y_pred = (y_proj >= threshold).astype(int)
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()
    
    # Type I error (False Positive Rate)
    type1_error = fp / (fp + tn) if (fp + tn) > 0 else 0.0
    
    # Type II error (False Negative Rate)
    type2_error = fn / (fn + tp) if (fn + tp) > 0 else 0.0
    
    return type1_error, type2_error

# Type1 and Type2 Error
def type_errors(y_true, y_pred):
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()
    
    # Type I error (False Positive Rate)
    type1_error = fp / (fp + tn) if (fp + tn) > 0 else 0.0
    
    # Type II error (False Negative Rate)
    type2_error = fn / (fn + tp) if (fn + tp) > 0 else 0.0
    
    return type1_error, type2_error

# %%
# predict test data
w = lda_projection_vector(train_x, train_y)
y_lda_test = test_x.dot(w)

# Given different thresholds, compute the type 1 and type 2 errors
lda_thresholds = np.linspace(y_lda_test.min(), y_lda_test.max(), 100)
type1_errors = []
type2_errors = []
for threshold in lda_thresholds:
    type1_error, type2_error = compute_error_rates(test_y, y_lda_test, threshold)
    type1_errors.append(type1_error)
    type2_errors.append(type2_error)

# %%
plt.figure(figsize=(10, 6))
plt.plot(lda_thresholds, type1_errors, label="Type I Error Rate (False Positive Rate)", color="blue")
plt.plot(lda_thresholds, type2_errors, label="Type II Error Rate (False Negative Rate)", color="red")
plt.xlabel("Threshold")
plt.ylabel("Error Rate")
plt.title("Type I and Type II Error Rates as a Function of Threshold")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## 1.2 Decision Tree
#
# Using the existing library DecisionTreeClassifier in sklearn, with parameter max_depth=10, the result is
#
# $$\begin{array}{cc}
# \text{Type1 Error} & \text{Type2 Error}\\ \hline
# 0.145 & 0.11
# \end{array}$$
#
# Visualization of the decision tree is also provided

# %%
dt = DecisionTreeClassifier(criterion="entropy", max_depth=10, random_state=4)
dt.fit(train_x, train_y)
y_dt_test = dt.predict(test_x)

# %%
dt_t1, dt_t2 = type_errors(test_y, y_dt_test)
print("type1 error rate for decision tree: ", dt_t1)
print("type2 error rate for decision tree: ", dt_t2)
# Out:
# type1 error rate for decision tree:  0.145
# type2 error rate for decision tree:  0.11

# %%
# Visualize the decision tree
print(tree.export_text(dt, feature_names=list(train.iloc[:, :-1].columns)))
# Out:
# |--- TotalDebtToIncomeRatio <= 0.22
# |   |--- TotalDebtToIncomeRatio <= 0.13
# |   |   |--- InterestRate <= 0.22
# |   |   |   |--- class: 1
# |   |   |--- InterestRate >  0.22
# |   |   |   |--- Annual Income <= 127607.50
# |   |   |   |   |--- Credit Score <= 572.50
# |   |   |   |   |   |--- Credit Score <= 462.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- Credit Score >  462.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- Credit Score >  572.50
# |   |   |   |   |   |--- NetWorth <= 7063.00
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- NetWorth >  7063.00
# |   |   |   |   |   |   |--- Payment History <= 22.50
# |   |   |   |   |   |   |   |--- Length of Credit History <= 10.00
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- Length of Credit History >  10.00
# |   |   |   |   |   |   |   |   |--- Checking Account Balance <= 4234.00
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- Checking Account Balance >  4234.00
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- Payment History >  22.50
# |   |   |   |   |   |   |   |--- Payment History <= 31.00
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- Payment History >  31.00
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- Annual Income >  127607.50
# |   |   |   |   |--- class: 1
# |   |--- TotalDebtToIncomeRatio >  0.13
# |   |   |--- InterestRate <= 0.26
# |   |   |   |--- Bankruptcy History <= 0.50
# |   |   |   |   |--- NetWorth <= 72600.50
# |   |   |   |   |   |--- Loan Duration <= 42.00
# |   |   |   |   |   |   |--- Number of Credit Inquries <= 3.50
# |   |   |   |   |   |   |   |--- Number of Dependents <= 3.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- Number of Dependents >  3.50
# |   |   |   |   |   |   |   |   |--- Length of Credit History <= 16.00
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- Length of Credit History >  16.00
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Number of Credit Inquries >  3.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- Loan Duration >  42.00
# |   |   |   |   |   |   |--- TotalDebtToIncomeRatio <= 0.16
# |   |   |   |   |   |   |   |--- Creditcard Utilizatio Rate <= 0.31
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- Creditcard Utilizatio Rate >  0.31
# |   |   |   |   |   |   |   |   |--- Debt to Income Ratio <= 0.26
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- Debt to Income Ratio >  0.26
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- TotalDebtToIncomeRatio >  0.16
# |   |   |   |   |   |   |   |--- Monthly Debt Payment <= 653.50
# |   |   |   |   |   |   |   |   |--- Savings Account Balance <= 992.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- Savings Account Balance >  992.50
# |   |   |   |   |   |   |   |   |   |--- Savings Account Balance <= 3648.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- Savings Account Balance >  3648.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- Monthly Debt Payment >  653.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- NetWorth >  72600.50
# |   |   |   |   |   |--- MonthlyIncome <= 3387.17
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- MonthlyIncome >  3387.17
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- Bankruptcy History >  0.50
# |   |   |   |   |--- Annual Income <= 93327.00
# |   |   |   |   |   |--- Credit Score <= 512.00
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- Credit Score >  512.00
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- Annual Income >  93327.00
# |   |   |   |   |   |--- class: 1
# |   |   |--- InterestRate >  0.26
# |   |   |   |--- NetWorth <= 80502.00
# |   |   |   |   |--- UtilityBillsPaymentHistory <= 0.59
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- UtilityBillsPaymentHistory >  0.59
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- NetWorth >  80502.00
# |   |   |   |   |--- Monthly Debt Payment <= 374.50
# |   |   |   |   |   |--- MonthlyLoanPayment <= 686.44
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- MonthlyLoanPayment >  686.44
# |   |   |   |   |   |   |--- Savings Account Balance <= 4553.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Savings Account Balance >  4553.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- Monthly Debt Payment >  374.50
# |   |   |   |   |   |--- class: 1
# |--- TotalDebtToIncomeRatio >  0.22
# |   |--- TotalDebtToIncomeRatio <= 0.36
# |   |   |--- InterestRate <= 0.23
# |   |   |   |--- NetWorth <= 162777.00
# |   |   |   |   |--- InterestRate <= 0.18
# |   |   |   |   |   |--- Length of Credit History <= 6.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- Length of Credit History >  6.50
# |   |   |   |   |   |   |--- Loan Amount <= 7319.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- Loan Amount >  7319.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- InterestRate >  0.18
# |   |   |   |   |   |--- Monthly Debt Payment <= 834.50
# |   |   |   |   |   |   |--- Credit Score <= 581.50
# |   |   |   |   |   |   |   |--- Total Assets <= 40971.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- Total Assets >  40971.50
# |   |   |   |   |   |   |   |   |--- Monthly Debt Payment <= 473.00
# |   |   |   |   |   |   |   |   |   |--- Loan Amount <= 19403.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- Loan Amount >  19403.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- Monthly Debt Payment >  473.00
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- Credit Score >  581.50
# |   |   |   |   |   |   |   |--- TotalDebtToIncomeRatio <= 0.24
# |   |   |   |   |   |   |   |   |--- UtilityBillsPaymentHistory <= 0.88
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- UtilityBillsPaymentHistory >  0.88
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- TotalDebtToIncomeRatio >  0.24
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- Monthly Debt Payment >  834.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- NetWorth >  162777.00
# |   |   |   |   |--- class: 1
# |   |   |--- InterestRate >  0.23
# |   |   |   |--- NetWorth <= 192701.50
# |   |   |   |   |--- MonthlyIncome <= 8999.67
# |   |   |   |   |   |--- UtilityBillsPaymentHistory <= 0.68
# |   |   |   |   |   |   |--- UtilityBillsPaymentHistory <= 0.67
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- UtilityBillsPaymentHistory >  0.67
# |   |   |   |   |   |   |   |--- MonthlyIncome <= 6130.12
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- MonthlyIncome >  6130.12
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- UtilityBillsPaymentHistory >  0.68
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- MonthlyIncome >  8999.67
# |   |   |   |   |   |--- Loan Amount <= 42267.00
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- Loan Amount >  42267.00
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- NetWorth >  192701.50
# |   |   |   |   |--- Credit Score <= 517.00
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- Credit Score >  517.00
# |   |   |   |   |   |--- Length of Credit History <= 23.00
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- Length of Credit History >  23.00
# |   |   |   |   |   |   |--- Payment History <= 16.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- Payment History >  16.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |--- TotalDebtToIncomeRatio >  0.36
# |   |   |--- Total Assets <= 363327.00
# |   |   |   |--- Annual Income <= 82830.50
# |   |   |   |   |--- class: 0
# |   |   |   |--- Annual Income >  82830.50
# |   |   |   |   |--- class: 1
# |   |   |--- Total Assets >  363327.00
# |   |   |   |--- MonthlyLoanPayment <= 876.51
# |   |   |   |   |--- Debt to Income Ratio <= 0.14
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- Debt to Income Ratio >  0.14
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- MonthlyLoanPayment >  876.51
# |   |   |   |   |--- class: 1

# %% [markdown]
# ## 1.3 K-nearest Neighbors
#
# Using the existing library in KNeighborsClassifier() sklearn, given k=1,3,5,10, the result is
# $$\begin{array}{ccc}
# k & \text{Type1 Error} & \text{Type2 Error}\\ \hline
# 1 & 0.25 & 0.185\\
# 3 & 0.185 & 0.17\\
# 5 & 0.2 & 0.135\\
# 10 & 0.17 & 0.165\\
# \end{array}$$

# %%
k_values = [1, 3, 5, 10]
knn_type1 = []
knn_type2 = []
for k in k_values:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(train_x, train_y)
    y_kn_pred = knn.predict(test_x)
    kn_t1, kn_t2 = type_errors(test_y, y_kn_pred)
    knn_type1.append(kn_t1)
    knn_type2.append(kn_t2)
    print("type1 error rate for kNN in k= ",k, "is", kn_t1)
    print("type2 error rate for kNN in k= ",k, "is", kn_t2)
# Out:
# type1 error rate for kNN in k=  1 is 0.25
# type2 error rate for kNN in k=  1 is 0.185
# type1 error rate for kNN in k=  3 is 0.185
# type2 error rate for kNN in k=  3 is 0.17
# type1 error rate for kNN in k=  5 is 0.2
# type2 error rate for kNN in k=  5 is 0.135
# type1 error rate for kNN in k=  10 is 0.17
# type2 error rate for kNN in k=  10 is 0.165

# %% [markdown]
# ## 1.4 Support Vector Machine
#
# SVC solves the following primal problem:
# $$min_{w,b,\zeta}\frac{1}{2}w^Tw+C\sum_{i=1}^n\zeta_i$$
# subject to $y_i(w^T\phi(x_i)+b)\geq 1-\zeta_i, \zeta_i\geq 0, i=1,...,n$
#
# In this question, $C=1$. The result is
# $$\begin{array}{cc}
# \text{Type1 Error} & \text{Type2 Error}\\ \hline
# 0.195 & 0.07
# \end{array}$$

# %%
svm = SVC(kernel='linear', C=1)
svm.fit(train_x, train_y)
y_svm_pred = svm.predict(test_x)

# %%
svm_t1, svm_t2 = type_errors(test_y, y_svm_pred)
print("type1 error rate for svm is", svm_t1)
print("type2 error rate for svm is", svm_t2)
# Out:
# type1 error rate for svm is 0.195
# type2 error rate for svm is 0.07

# %% [markdown]
# ## 2.1 kNN After PCA
#
# Using the existing library PCA in sklearn, given different number of components (5, 10, 15), the results of kNN classifier with different k (1, 3, 5, 10) are
# $$\begin{array}{cccc}
# kNN & \text{PCA components} & \text{Type1 Error} & \text{Type2 Error}\\ \hline
# 1 & 5 & 0.235 & 0.2\\
# 1 & 10 & 0.25 & 0.185\\
# 1 & 15 & 0.25 & 0.185\\
# 3 & 5 & 0.18 & 0.17\\
# 3 & 10 & 0.185 & 0.17\\
# 3 & 15 & 0.185 & 0.17\\
# 5 & 5 & 0.19 & 0.125\\
# 5 & 10 & 0.2 & 0.135\\
# 5 & 15 & 0.2 & 0.135\\
# 10 & 5 & 0.165 & 0.155\\
# 10 & 10 & 0.17 & 0.165\\
# 10 & 15 & 0.17 & 0.165\\
# \end{array}$$

# %%
n_com = [5, 10, 15]
pca = [PCA(n_components=n) for n in n_com]
pca_fit = [pca[i].fit_transform(train_x) for i in range(len(pca))]
pca_test_x = [pca[i].transform(test_x) for i in range(len(pca))]

# %%
pca_fit[0].shape, pca_fit[1].shape, pca_fit[2].shape, pca_test_x[0].shape, pca_test_x[1].shape, pca_test_x[2].shape
# Out:
# ((900, 5), (900, 10), (900, 15), (400, 5), (400, 10), (400, 15))

# %%
pca_knn_type1 = []
pca_knn_type2 = []
for k in k_values:
    for i, f in enumerate(pca_fit):
        knn = KNeighborsClassifier(n_neighbors=k)
        knn.fit(pca_fit[i], train_y)
        y_pca_kn_pred = knn.predict(pca_test_x[i])
        pca_kn_t1, pca_kn_t2 = type_errors(test_y, y_pca_kn_pred)
        pca_knn_type1.append(pca_kn_t1)
        pca_knn_type2.append(pca_kn_t2)
        print("type1 error rate for kNN in k= ",k, "and PCA component=", n_com[i], "is", pca_kn_t1)
        print("type2 error rate for kNN in k= ",k, "and PCA component=", n_com[i], "is", pca_kn_t2)
# Out:
# type1 error rate for kNN in k=  1 and PCA component= 5 is 0.235
# type2 error rate for kNN in k=  1 and PCA component= 5 is 0.2
# type1 error rate for kNN in k=  1 and PCA component= 10 is 0.25
# type2 error rate for kNN in k=  1 and PCA component= 10 is 0.185
# type1 error rate for kNN in k=  1 and PCA component= 15 is 0.25
# type2 error rate for kNN in k=  1 and PCA component= 15 is 0.185
# type1 error rate for kNN in k=  3 and PCA component= 5 is 0.18
# type2 error rate for kNN in k=  3 and PCA component= 5 is 0.17
# type1 error rate for kNN in k=  3 and PCA component= 10 is 0.185
# type2 error rate for kNN in k=  3 and PCA component= 10 is 0.17
# type1 error rate for kNN in k=  3 and PCA component= 15 is 0.185
# type2 error rate for kNN in k=  3 and PCA component= 15 is 0.17
# type1 error rate for kNN in k=  5 and PCA component= 5 is 0.19
# type2 error rate for kNN in k=  5 and PCA component= 5 is 0.125
# type1 error rate for kNN in k=  5 and PCA component= 10 is 0.2
# type2 error rate for kNN in k=  5 and PCA component= 10 is 0.135
# type1 error rate for kNN in k=  5 and PCA component= 15 is 0.2
# type2 error rate for kNN in k=  5 and PCA component= 15 is 0.135
# type1 error rate for kNN in k=  10 and PCA component= 5 is 0.165
# type2 error rate for kNN in k=  10 and PCA component= 5 is 0.155
# type1 error rate for kNN in k=  10 and PCA component= 10 is 0.17
# type2 error rate for kNN in k=  10 and PCA component= 10 is 0.165
# type1 error rate for kNN in k=  10 and PCA component= 15 is 0.17
# type2 error rate for kNN in k=  10 and PCA component= 15 is 0.165

# %%
# Type 1
lables = ("1 kNN", "3 kNN", "5 kNN", "10 kNN")
data = {
    '5 PCA components': tuple(pca_knn_type1[0::3]),
    '10 PCA components': tuple(pca_knn_type1[1::3]),
    '15 PCA components' : tuple(pca_knn_type1[2::3]),
    'NO PCA' : tuple(knn_type1)
}
x = np.arange(len(lables))  # the label locations
width = 0.23  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(figsize=(12, 6))

for attribute, measurement in data.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    ax.bar_label(rects, padding=3)
    multiplier += 1

ax.set_ylabel('Type1 Error Rate')
ax.set_xlabel('kNN')
ax.set_title('Type1 Error Rate Given different PCA components number and kNN')
ax.set_xticks(x + width, lables)
ax.legend(loc='upper left', ncols=4)
ax.set_ylim(0, 0.4)

plt.show()

# %%
# Type 2
lables = ("1 kNN", "3 kNN", "5 kNN", "10 kNN")
data = {
    '5 PCA components': tuple(pca_knn_type2[0::3]),
    '10 PCA components': tuple(pca_knn_type2[1::3]),
    '15 PCA components' : tuple(pca_knn_type2[2::3]),
    'NO PCA' : tuple(knn_type2)
}
x = np.arange(len(lables))  # the label locations
width = 0.23  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(figsize=(12, 6))

for attribute, measurement in data.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    ax.bar_label(rects, padding=3)
    multiplier += 1

ax.set_ylabel('Type2 Error Rate')
ax.set_xlabel('kNN')
ax.set_title('Type2 Error Rate Given different PCA components number and kNN')
ax.set_xticks(x + width, lables)
ax.legend(loc='upper left', ncols=4)
ax.set_ylim(0, 0.4)

plt.show()

# %% [markdown]
# We can see in most cases, when setting PCA components number to 5, both Type1 Error rate and Type2 Error rate become slightly lower.
#
# That means the dimensionality reduction with 5 principal components can effectively capture the essential features of the data, and it may reduce some noise compare to the original data.

# %% [markdown]
# ## 2.2 SVM After PCA

# %%
pca_svm_type1 = []
pca_svm_type2 = []
for i, n in enumerate(n_com):
    svm = SVC(kernel='linear', C=1)
    svm.fit(pca_fit[i], train_y)
    y_pca_svm_pred = svm.predict(pca_test_x[i])
    pca_svm_t1, pca_svm_t2 = type_errors(test_y, y_pca_kn_pred)
    pca_svm_type1.append(pca_svm_t1)
    pca_svm_type2.append(pca_svm_t2)
    print("type1 error rate for SVM in PCA component=", n_com[i], "is", pca_svm_t1)
    print("type2 error rate for SVM in PCA component=", n_com[i], "is", pca_svm_t2)
