# %%
import numpy as np

# %%
X = np.array([1.2, 1.7, -1.3])
w = np.array([0.707, -0.707, 0])
np.dot(X, w) / np.linalg.norm(w) * w
# Out:
# array([-0.24996225,  0.24996225, -0.        ])

# %%
w = np.array([1, -0.5, 2])
x = np.array([1, -3, 2])
# (w@x.T - 2) / np.linalg.norm(w)
# w @ x.T - 2
2/np.linalg.norm(w)
# Out:
# 1.9639610121239315

# %% [markdown]
# 1. 逆矩阵

# %%
A = np.array([[1,2], [3,4]])

inverse_A = np.linalg.inv(A)

inverse_A

# %% [markdown]
# 2. 特征向量，特征值

# %%
A = np.array([[7.5, 2.5, 0], [2.5, 7.5, 0], [0, 0, 2]])
eigenvalues, eigenvectors = np.linalg.eig(A)
eigenvalues, eigenvectors
-0.3536 * eigenvectors[0]
# Out:
# array([-0.25003296,  0.25003296, -0.        ])

# %% [markdown]
# 3. 奇异值分解

# %%
B = np.array([[1.2, 0.9, -4], [1.6, 1.2, 3]])
U, S, Vt = np.linalg.svd(B)
U, S, Vt
# Out:
# (array([[-0.8,  0.6],
#         [ 0.6,  0.8]]),
#  array([5. , 2.5]),
#  array([[-1.15228279e-16, -4.33065218e-17,  1.00000000e+00],
#         [ 8.00000000e-01,  6.00000000e-01, -1.16877487e-16],
#         [ 6.00000000e-01, -8.00000000e-01, -5.55111512e-17]]))

# %% [markdown]
# 4. log

# %%
x = 10
np.log(x), np.log2(3), np.log(x) / np.log(5)
5/3*np.log(76)-5/2
# Out:
# 4.717888900477218

# %% [markdown]
# 5. 导数、积分表
# 导数：https://baike.baidu.com/item/%E5%AF%BC%E6%95%B0%E8%A1%A8/10889755
# 不定积分：https://zh.wikipedia.org/wiki/%E4%B8%8D%E5%AE%9A%E7%A7%AF%E5%88%86

# %% [markdown]
# 6. PCA

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
principal_components = pca.fit_transform(data - data.mean())
w1, w2 = pca.components_

# %% [markdown]
# 7. LDA

# %%
m1 = np.mean(D1, axis=0)
d1 = D1 - m1
w1 = np.dot(d1.T, d1)
m2 = np.mean(D2, axis=0)
d2 = D2 - m2
w2 = np.dot(d2.T, d2)
Sw = w1+w2
Swinv = np.linalg.inv(Sw)
w = Swinv @ (m1 - m2)
print('mean of class 1 is ', m1)
print('mean of class 2 is ', m2)
print('within-class scatter matrix is ')
print(Sw)
print('The value of w is ')
print(w)

# %% [markdown]
# 8. Entropy and Gini Impurity

# %%
from scipy.stats import entropy
entropy([1/3, 1/3, 1/3], base=2)
# Out:
# 1.584962500721156

# %% [markdown]
# ## Spectral Clustering

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import SpectralClustering
from sklearn.datasets import make_moons

# Step 1: Generate a synthetic dataset
X, y = make_moons(n_samples=300, noise=0.05, random_state=42)

# Step 2: Apply Spectral Clustering
spectral = SpectralClustering(n_clusters=2, affinity='nearest_neighbors', random_state=42)
labels = spectral.fit_predict(X)

# Step 3: Visualization of Results
plt.figure(figsize=(8, 6))
plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis', s=50)
plt.title("Spectral Clustering on Non-Linearly Separable Data")
plt.show()
# Out:
# C:\Users\henry\AppData\Roaming\Python\Python312\site-packages\sklearn\manifold\_spectral_embedding.py:329: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(

# %% [markdown]
# ## Multi-Dimensional Scaling
